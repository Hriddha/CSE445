# %%
try:
    import pyscreenshot as ImageGrab
except ImportError:
    import sys
    # !{sys.executable} -m pip install pyscreenshot
    import pyscreenshot as ImageGrab

import time
import time

# %%
images_folder="./captured"
# Out:
# str
